# %%
import pandas as pd
import numpy as np
import re
import tweepy
import matplotlib.pyplot as plt
from textblob import TextBlob

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Load the dataset
import pandas as pd
df = pd.read_csv('/content/drive/My Drive/Colab Notebooks/NFRF ML/ElectionTweets.csv')
df
# Out:
#       Unnamed: 0                                             Tweets
# 0              0  CAN Decries Naira Shortage, Urges Buhari To Ea...
# 1              1  Zamfara Commissioner Mafara Resigns, Defects T...
# 2              2  This election is between PO and Atiku...Apc/Ti...
# 3              3                        This jungle don over mature
# 4              4                     Corrupt politicians are moving
# ...          ...                                                ...
# 3041        3041  Under dis present govt custom as increased dut...
# 3042        3042  I will recommend the \n@NGRSenate\n \n@nassnig...
# 3043        3043  Allow the owners to come and claim their cargo...
# 3044        3044  All the criminals in Nigeria are now quick to ...
# 3045        3045  lol, a scenario where the movement behind LP m...
#
# [3046 rows x 2 columns]

# %%
import nltk
from nltk.corpus import stopwords
nltk.download('stopwords')
def clean_tweet(df):
    # Remove special characters, URLs, and usernames
    cleaned_tweet = re.sub(r'https?://\S+|www\.\S+|@[A-Za-z0-9]+', '', df)

    # Remove punctuation and numbers
    cleaned_tweet = re.sub(r'[^a-zA-Z]', ' ', cleaned_tweet)

    # Convert to lowercase
    cleaned_tweet = cleaned_tweet.lower()

    # Tokenize the text
    words = cleaned_tweet.split()

    # Remove stop words
    stop_words = set(stopwords.words('english'))
    words = [word for word in words if word not in stop_words]

    # Join the words back into a cleaned tweet
    cleaned_tweet = ' '.join(words)

    return cleaned_tweet
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
def analyze_sentiment(df):
    analysis = TextBlob(df)

    # Determine sentiment polarity
    if analysis.sentiment.polarity > 0:
        return 'Positive'
    elif analysis.sentiment.polarity == 0:
        return 'Neutral'
    else:
        return 'Negative'

# %%
df
# Out:
#       Unnamed: 0                                             Tweets
# 0              0  CAN Decries Naira Shortage, Urges Buhari To Ea...
# 1              1  Zamfara Commissioner Mafara Resigns, Defects T...
# 2              2  This election is between PO and Atiku...Apc/Ti...
# 3              3                        This jungle don over mature
# 4              4                     Corrupt politicians are moving
# ...          ...                                                ...
# 3041        3041  Under dis present govt custom as increased dut...
# 3042        3042  I will recommend the \n@NGRSenate\n \n@nassnig...
# 3043        3043  Allow the owners to come and claim their cargo...
# 3044        3044  All the criminals in Nigeria are now quick to ...
# 3045        3045  lol, a scenario where the movement behind LP m...
#
# [3046 rows x 2 columns]

# %%
#Using DataFrame.drop() method.
df2=df.drop(df.columns[0], axis=1)
df2
# Out:
#                                                  Tweets
# 0     CAN Decries Naira Shortage, Urges Buhari To Ea...
# 1     Zamfara Commissioner Mafara Resigns, Defects T...
# 2     This election is between PO and Atiku...Apc/Ti...
# 3                           This jungle don over mature
# 4                        Corrupt politicians are moving
# ...                                                 ...
# 3041  Under dis present govt custom as increased dut...
# 3042  I will recommend the \n@NGRSenate\n \n@nassnig...
# 3043  Allow the owners to come and claim their cargo...
# 3044  All the criminals in Nigeria are now quick to ...
# 3045  lol, a scenario where the movement behind LP m...
#
# [3046 rows x 1 columns]

# %%
#Create a function to get the subjectivity
def getSubjectivity(twt):
	return TextBlob(twt).sentiment.subjectivity

#Create a function to get the polarity

def getPolarity(twt):
	return TextBlob(twt).sentiment.polarity

# %%
#Create two new column for our dataset and it will hold the subjectivity and polarity
df2['Subjectivity']=df2['Tweets'].apply(getSubjectivity)
df2['Polarity']=df2['Tweets'].apply(getPolarity)
#Show the data
df2.head(10)
# Out:
#                                               Tweets  \
# 0  CAN Decries Naira Shortage, Urges Buhari To Ea...
# 1  Zamfara Commissioner Mafara Resigns, Defects T...
# 2  This election is between PO and Atiku...Apc/Ti...
# 3                        This jungle don over mature
# 4                     Corrupt politicians are moving
# 5  Kwankwaso Rejects Pre-Election Polls, Says NNP...
# 6  Please show Kwankwaso this video, it will help...
# 7          NNPP has locked Kwankwaso polling station
# 8  Even all the crowd in kwankwaso camp still Pet...
# 9  Kwakwanso thought government of Peter Obi is g...
#
#                                        Cleaned_Tweet Sentiment  Subjectivity  \
# 0  decries naira shortage urges buhari ease niger...   Neutral          0.00
# 1    zamfara commissioner mafara resigns defects pdp   Neutral          0.00
# 2  election po atiku apc tinubu would come distan...  Negative          0.35
# ...

# %%
df2.to_csv ("ElectionSentimentResult.csv",
                  index = None,
                  header=True)

# %%
path = '/content/drive/My Drive/Colab Notebooks/NFRF ML/ElectionSentimentResult.csv'
with open(path, 'w', encoding = 'utf-8-sig') as f:
  df2.to_csv(f)
